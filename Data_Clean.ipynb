# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ftfy

# %%
data = pd.read_csv("book_data.csv")

# %%
data
# Out:
#                                                   author bookformat  \
# 0                                   Laurence M. Hauptman  Hardcover
# 1                       Charlotte Fiell,Emmanuelle Dirix  Paperback
# 2                                          Andy Anderson  Paperback
# 3                                   Carlotta R. Anderson  Hardcover
# 4                                          Jean Leveille        NaN
# ...                                                  ...        ...
# 99995                                         Simon Monk      ebook
# 99996  Tracie L. Miller-Nobles,Brenda L. Mattison,Ell...  Hardcover
# 99997                                     C. John Miller  Paperback
# 99998                                      Albert Marrin  Hardcover
# 99999                                      Marc E. Fitch      ebook
#
#                                                     desc  \
# 0      Reveals that several hundred thousand Indians ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   author        100000 non-null  object
#  1   bookformat    96772 non-null   object
#  2   desc          93228 non-null   object
#  3   genre         89533 non-null   object
#  4   img           96955 non-null   object
#  5   isbn          85518 non-null   object
#  6   isbn13        88565 non-null   object
#  7   link          100000 non-null  object
#  8   pages         100000 non-null  int64
#  9   rating        100000 non-null  float64
#  10  reviews       100000 non-null  int64
#  11  title         99999 non-null   object
#  12  totalratings  100000 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 9.9+ MB

# %%
data = data.drop(columns = "isbn")

# %%
data = data.drop(columns = "isbn13")

# %%
data
# Out:
#                                                   author bookformat  \
# 0                                   Laurence M. Hauptman  Hardcover
# 1                       Charlotte Fiell,Emmanuelle Dirix  Paperback
# 2                                          Andy Anderson  Paperback
# 3                                   Carlotta R. Anderson  Hardcover
# 4                                          Jean Leveille        NaN
# ...                                                  ...        ...
# 99995                                         Simon Monk      ebook
# 99996  Tracie L. Miller-Nobles,Brenda L. Mattison,Ell...  Hardcover
# 99997                                     C. John Miller  Paperback
# 99998                                      Albert Marrin  Hardcover
# 99999                                      Marc E. Fitch      ebook
#
#                                                     desc  \
# 0      Reveals that several hundred thousand Indians ...
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83520 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   author        83520 non-null  object
#  1   bookformat    83520 non-null  object
#  2   desc          83520 non-null  object
#  3   genre         83520 non-null  object
#  4   img           83520 non-null  object
#  5   link          83520 non-null  object
#  6   pages         83520 non-null  int64
#  7   rating        83520 non-null  float64
#  8   reviews       83520 non-null  int64
#  9   title         83520 non-null  object
#  10  totalratings  83520 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 7.6+ MB

# %%
rating_counts = data.groupby(['title', 'author']).rating.count().reset_index(name='rating_count')

# Print the rating counts to understand the distribution
print("Rating Counts:")
print(rating_counts)
# Out:
# Rating Counts:
#                                                    title  \
# 0                                             "Daisuki."
# 1                      "Dark Pictures" and Other Stories
# 2                 "Defects": Engendering the Modern Body
# 3                                  "Have-More" Plan, The
# 4      "Headhunter" Hiring Secrets: The Rules of the ...
# ...                                                  ...
# 83484                                ì•„ì´ëŒ ì‡¼í•‘. 7
# 83485                                ì•„ì´ëŒ ì‡¼í•‘. 8
# 83486                                       ì•…ì˜ ê½ƒ 5
# 83487                                í•˜ë°±ì˜ ì‹ ë¶€ 14
# 83488                                í•˜ë°±ì˜ ì‹ ë¶€ 15
#
#                                                 author  rating_count
# 0                                     Hildred Billings             1
# 1                                         Hiroshi Noma             1
# ...

# %%
data['genre'] = data['genre'].str.split(',').str[0]

# %%
data.drop_duplicates(['title'], inplace = True)
final = data[data['totalratings']>=20]

# %%
book_pivot = final.pivot_table(columns = 'genre', index = 'title', values = 'rating')

# %%
book_pivot
# Out:
# genre                                               40k  Academic  Action  \
# title
# "Daisuki."                                          NaN       NaN     NaN
# "Have-More" Plan, The                               NaN       NaN     NaN
# "Headhunter" Hiring Secrets: The Rules of the H...  NaN       NaN     NaN
# "It's Not About the Sex" My Ass                     NaN       NaN     NaN
# "Let's Get a Pup!" Said Kate                        NaN       NaN     NaN
# ...                                                 ...       ...     ...
# ì•„ì´ëŒ ì‡¼í•‘. 7                                 NaN       NaN     NaN
# ì•„ì´ëŒ ì‡¼í•‘. 8                                 NaN       NaN     NaN
# ì•…ì˜ ê½ƒ 5                                        NaN       NaN     NaN
# í•˜ë°±ì˜ ì‹ ë¶€ 14                                 NaN       NaN     NaN
# í•˜ë°±ì˜ ì‹ ë¶€ 15                                 NaN       NaN     NaN
#
# ...
